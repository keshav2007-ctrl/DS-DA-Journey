# %%
import pandas as pd
# df = pd.read_csv('archive/fifa_world_cup_2026_player_performance.csv')
# df["player_name"][0] = "Lionel Messi", Pandas does not allow direct assignment to a single cell in a DataFrame using the bracket notation.
# print(df)
# print(df.head())
# print(df.shape)
# print(df.describe())

# # How many unique nationalities?
# print(df['nationality'].nunique())

# # Which nationality has the most players?
# print(df['nationality'].value_counts().head(10))

# # Average age of all players
# print(df['age'].mean())

# # Filter only Spanish players
# spanish = df[df['nationality'] == 'Spanish']
# print(spanish.shape)

# # Top 5 players by tournament rating
# print(df.sort_values('tournament_rating', ascending=False).head())

# # Average tournament rating by nationality (top 10)
# print(df.groupby('nationality')['tournament_rating'].mean().sort_values(ascending=False).head(10))

# # Youngest and oldest player
# print(df['age'].min(), df['age'].max())

# # Players above average rating
# avg = df['tournament_rating'].mean()
# top = df[df['tournament_rating'] > avg]
# print(top.shape)

# %% [markdown]
# 1. A one dimensional array capable of holding any data is series
# 2. A two dimensional array structured with columns of potentially diffrent types of data is DataFrame

# %%
import pandas as pd
# s = pd.Series([1, 2, 3, 4, 5])
# print(s)

# %%
import pandas as pd
Dict1 = {"Name": ["Alice", "Bob", "Charlie", "David"],
         "Age": [25, 30, 35, 40],
         "City": ["New York", "Los Angeles", "Chicago", "Houston"]}

df = pd.DataFrame(Dict1)

df.index = ["1", "2", "3", "4"]
df.to_csv("dict1.csv", index=True)
print(pd.read_csv("dict1.csv", index_col=0))
# Out:
#       Name  Age         City
# 1    Alice   25     New York
# 2      Bob   30  Los Angeles
# 3  Charlie   35      Chicago
# 4    David   40      Houston

# %%
import numpy as np
import pandas as pd
newdf1 = pd.DataFrame(np.random.rand(544, 6), columns=['A', 'B', 'C', 'D', 'E', 'F'])

# %%
newdf1
# Out:
#             A         B         C         D         E         F
# 0    0.188342  0.309572  0.937650  0.888954  0.979147  0.083887
# 1    0.434122  0.962318  0.871722  0.949635  0.344015  0.791202
# 2    0.277477  0.758229  0.336202  0.339409  0.878380  0.970506
# 3    0.189065  0.054653  0.576982  0.762518  0.986222  0.229982
# 4    0.430847  0.474358  0.710821  0.169198  0.267734  0.413888
# ..        ...       ...       ...       ...       ...       ...
# 539  0.553191  0.562249  0.991340  0.609532  0.002547  0.204022
# 540  0.011255  0.701804  0.055162  0.716890  0.055954  0.858527
# 541  0.291350  0.356051  0.662655  0.964576  0.813787  0.501308
# 542  0.243525  0.356796  0.132848  0.357949  0.698828  0.517909
# 543  0.461277  0.801977  0.397309  0.151586  0.834628  0.071598
#
# [544 rows x 6 columns]

# %%
newdf1.head()
# Out:
#           A         B         C         D         E         F
# 0  0.188342  0.309572  0.937650  0.888954  0.979147  0.083887
# 1  0.434122  0.962318  0.871722  0.949635  0.344015  0.791202
# 2  0.277477  0.758229  0.336202  0.339409  0.878380  0.970506
# 3  0.189065  0.054653  0.576982  0.762518  0.986222  0.229982
# 4  0.430847  0.474358  0.710821  0.169198  0.267734  0.413888

# %%
newdf1.loc[0:5, ['A', 'B']]
# Out:
#           A         B
# 0  0.188342  0.309572
# 1  0.434122  0.962318
# 2  0.277477  0.758229
# 3  0.189065  0.054653
# 4  0.430847  0.474358
# 5  0.332656  0.481680

# %%
newdf1.loc[[4,5], :]
# Out:
#           A         B         C         D         E         F
# 4  0.430847  0.474358  0.710821  0.169198  0.267734  0.413888
# 5  0.332656  0.481680  0.895049  0.955645  0.247785  0.312787

# %%
newdf1.loc[: ,["C", "D"]]
# Out:
#             C         D
# 0    0.937650  0.888954
# 1    0.871722  0.949635
# 2    0.336202  0.339409
# 3    0.576982  0.762518
# 4    0.710821  0.169198
# ..        ...       ...
# 539  0.991340  0.609532
# 540  0.055162  0.716890
# 541  0.662655  0.964576
# 542  0.132848  0.357949
# 543  0.397309  0.151586
#
# [544 rows x 2 columns]

# %%
newdf1.loc[(newdf1['A'] > 0.5) & (newdf1['B'] < 0.5)]
# Out:
#             A         B         C         D         E         F
# 7    0.513222  0.459120  0.274179  0.627615  0.855615  0.506563
# 8    0.566823  0.154601  0.262781  0.065991  0.227707  0.985835
# 15   0.576708  0.495432  0.802419  0.025809  0.353777  0.906121
# 17   0.820299  0.208397  0.591363  0.044501  0.851213  0.022375
# 20   0.525750  0.315837  0.620371  0.346708  0.946603  0.388962
# ..        ...       ...       ...       ...       ...       ...
# 521  0.540835  0.032219  0.591831  0.821273  0.874687  0.614593
# 526  0.941928  0.356455  0.615886  0.451019  0.634871  0.241884
# 532  0.700523  0.173720  0.182951  0.370073  0.072004  0.031341
# 534  0.827052  0.161309  0.319717  0.481128  0.849008  0.386847
# 535  0.749008  0.162986  0.773173  0.728568  0.968980  0.460036
#
# [136 rows x 6 columns]

# %%
newdf1.iloc[0,5]
# Out:
# np.float64(0.0838874140495326)

# %%
newdf1.drop([0])
# Out:
#             A         B         C         D         E         F
# 1    0.434122  0.962318  0.871722  0.949635  0.344015  0.791202
# 2    0.277477  0.758229  0.336202  0.339409  0.878380  0.970506
# 3    0.189065  0.054653  0.576982  0.762518  0.986222  0.229982
# 4    0.430847  0.474358  0.710821  0.169198  0.267734  0.413888
# 5    0.332656  0.481680  0.895049  0.955645  0.247785  0.312787
# ..        ...       ...       ...       ...       ...       ...
# 539  0.553191  0.562249  0.991340  0.609532  0.002547  0.204022
# 540  0.011255  0.701804  0.055162  0.716890  0.055954  0.858527
# 541  0.291350  0.356051  0.662655  0.964576  0.813787  0.501308
# 542  0.243525  0.356796  0.132848  0.357949  0.698828  0.517909
# 543  0.461277  0.801977  0.397309  0.151586  0.834628  0.071598
#
# [543 rows x 6 columns]

# %% [markdown]
# inplace = true modifies the original DataFrame

# %%
newdf1
# Out:
#             A         B         C         D         E         F
# 0    0.188342  0.309572  0.937650  0.888954  0.979147  0.083887
# 1    0.434122  0.962318  0.871722  0.949635  0.344015  0.791202
# 2    0.277477  0.758229  0.336202  0.339409  0.878380  0.970506
# 3    0.189065  0.054653  0.576982  0.762518  0.986222  0.229982
# 4    0.430847  0.474358  0.710821  0.169198  0.267734  0.413888
# ..        ...       ...       ...       ...       ...       ...
# 539  0.553191  0.562249  0.991340  0.609532  0.002547  0.204022
# 540  0.011255  0.701804  0.055162  0.716890  0.055954  0.858527
# 541  0.291350  0.356051  0.662655  0.964576  0.813787  0.501308
# 542  0.243525  0.356796  0.132848  0.357949  0.698828  0.517909
# 543  0.461277  0.801977  0.397309  0.151586  0.834628  0.071598
#
# [544 rows x 6 columns]

# %%
newdf1.drop([1], inplace = True)

# %%
newdf1.shape
# Out:
# (543, 6)

# %%
newdf1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 543 entries, 0 to 543
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       543 non-null    float64
#  1   B       543 non-null    float64
#  2   C       543 non-null    float64
#  3   D       543 non-null    float64
#  4   E       543 non-null    float64
#  5   F       543 non-null    float64
# dtypes: float64(6)
# memory usage: 29.7 KB

# %%
newdf1['A'].value_counts()
# Out:
# A
# 0.188342    1
# 0.277477    1
# 0.189065    1
# 0.430847    1
# 0.332656    1
#            ..
# 0.553191    1
# 0.011255    1
# 0.291350    1
# 0.243525    1
# 0.461277    1
# Name: count, Length: 543, dtype: int64

# %%
newdf1.describe()
newdf1.corr()
newdf1.mean()
newdf1.min()
# newdf1.max()
# newdf1.median()
# newdf1.std()
# newdf1.count()
# Out:
# A    0.001875
# B    0.002976
# C    0.000735
# D    0.000437
# E    0.001611
# F    0.002188
# dtype: float64

# %%
newdf1.iloc[-5:, 0]
# Out:
# 539    0.553191
# 540    0.011255
# 541    0.291350
# 542    0.243525
# 543    0.461277
# Name: A, dtype: float64

# %%
df = pd.read_csv('C:\\DS_Quant_journey\\PYTHON\\archive\\fifa_world_cup_2026_player_performance.csv')

# %%
df.nationality == 'Italian'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54595    False
# 54596    False
# 54597    False
# 54598    False
# 54599    False
# Name: nationality, Length: 54600, dtype: bool

# %%
df.loc[(df.nationality == 'Italian') | (df.tournament_rating>= 6.0)]
# Out:
#       player_id        player_name  age nationality   team  jersey_number  \
# 2        P00066         Gavi Ramos   18     Spanish  Spain             14
# 3        P00073      Pedro Cubarsi   20     Spanish  Spain             21
# 5        P00072          Dani Gavi   21     Spanish  Spain             20
# 6        P00058      Rodri Laporte   27     Spanish  Spain              6
# 7        P00078          Ansu Fati   27     Spanish  Spain             26
# ...         ...                ...  ...         ...    ...            ...
# 54577    P01009    Mohannad Majeed   18       Iraqi   Iraq             21
# 54580    P00992  Mohannad Al-Amiri   26       Iraqi   Iraq              4
# 54584    P00995        Ali Mohanad   27       Iraqi   Iraq              7
# 54585    P00999       Ahmed Moutan   26       Iraqi   Iraq             11
# 54587    P01001  Mohannad Al-Saadi   29       Iraqi   Iraq             13
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# 2      Midfielder        177         72           Left  ...              15.3
# 3         Forward        182         74          Right  ...               1.2
# 5      Midfielder        181         78          Right  ...              17.0
# 6        Defender        188         80          Right  ...               6.4
# 7         Forward        182         72          Right  ...               2.4
# ...           ...        ...        ...            ...  ...               ...
# 54577     Forward        187         75          Right  ...              10.5
# 54580    Defender        186         80          Right  ...              12.5
# 54584    Defender        188         84           Left  ...               4.0
# 54585    Defender        187         80          Right  ...              10.2
# 54587  Midfielder        175         79          Right  ...               2.8
#
#        pressure_resistance creativity_score consistency_score  \
# 2                     99.0             99.0              83.4
# 3                     19.8             42.3              40.9
# 5                     65.4             85.8              91.1
# 6                     48.7             15.3              61.8
# 7                     48.2             35.6              60.9
# ...                    ...              ...               ...
# 54577                 81.5             99.0              93.1
# 54580                 99.0             21.6              73.5
# 54584                 55.5             42.3              42.5
# 54585                 86.2             21.7              99.0
# 54587                 84.2             73.9              87.6
#
#       clutch_performance_score total_goals_tournament  \
# 2                         54.8                      1
# 3                         78.5                      5
# 5                         48.2                      1
# 6                         55.1                      0
# 7                         60.4                      2
# ...                        ...                    ...
# 54577                     99.0                      3
# 54580                     74.6                      0
# 54584                     35.0                      0
# 54585                     99.0                      0
# 54587                     89.7                      2
#
#       total_assists_tournament total_minutes_tournament  \
# 2                            1                      245
# 3                            3                      422
# 5                            2                      332
# 6                            1                      264
# 7                            1                      191
# ...                        ...                      ...
# 54577                        0                      288
# 54580                        0                      459
# 54584                        1                      135
# 54585                        0                      246
# 54587                        0                      216
#
#       player_of_match_awards  tournament_rating
# 2                          0                8.4
# 3                          0                6.7
# 5                          0                6.7
# 6                          0                7.0
# 7                          0                6.8
# ...                      ...                ...
# 54577                      2                6.0
# 54580                      0                7.5
# 54584                      0                6.4
# 54585                      0                6.9
# 54587                      0                6.1
#
# [21698 rows x 75 columns]
